# %%
import json
import plotly.express as px
import dash
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
import plotly.graph_objects as go
import glob

# %%
f_names = glob.glob("./**", recursive=True)

# %%
f_names = [fn for fn in f_names if "trainer_state" in fn]

# %%
f_names
# Out:
# ['./training_states/6184d3d8-3de9-4b16-b11d-7f7bd8ec1821_TransformerPlusTemporal/checkpoint-60000/trainer_state.json',
#  './training_states/6184d3d8-3de9-4b16-b11d-7f7bd8ec1821_TransformerPlusTemporal/checkpoint-40000/trainer_state.json',
#  './training_states/6184d3d8-3de9-4b16-b11d-7f7bd8ec1821_TransformerPlusTemporal/checkpoint-100000/trainer_state.json',
#  './training_states/6184d3d8-3de9-4b16-b11d-7f7bd8ec1821_TransformerPlusTemporal/checkpoint-80000/trainer_state.json',
#  './training_states/3bfa095a-7fe5-42aa-8d89-e780c3933abb_TransformerPlusTemporal/checkpoint-6000/trainer_state.json',
#  './training_states/3bfa095a-7fe5-42aa-8d89-e780c3933abb_TransformerPlusTemporal/checkpoint-9000/trainer_state.json',
#  './training_states/3bfa095a-7fe5-42aa-8d89-e780c3933abb_TransformerPlusTemporal/checkpoint-15000/trainer_state.json',
#  './training_states/3bfa095a-7fe5-42aa-8d89-e780c3933abb_TransformerPlusTemporal/checkpoint-12000/trainer_state.json',
#  './training_states/a530e81d-59f1-4d2e-b1a8-8025d74704e2_TransformerLikeFu/checkpoint-60000/trainer_state.json',
#  './training_states/a530e81d-59f1-4d2e-b1a8-8025d74704e2_TransformerLikeFu/checkpoint-40000/trainer_state.json',
#  './training_states/a530e81d-59f1-4d2e-b1a8-8025d74704e2_TransformerLikeFu/checkpoint-20000/trainer_state.json',
#  './training_states/a530e81d-59f1-4d2e-b1a8-8025d74704e2_TransformerLikeFu/checkpoint-80000/trainer_state.json',
#  './training_states/dfbf73de-a3e3-48a6-841a-3e926031e249_TransformerPlusTemporal/checkpoint-6000/trainer_state.json',
#  './training_states/dfbf73de-a3e3-48a6-841a-3e926031e249_TransformerPlusTemporal/checkpoint-9000/trainer_state.json',
#  './training_states/dfbf73de-a3e3-48a6-841a-3e926031e249_TransformerPlusTemporal/checkpoint-3000/trainer_state.json',
#  './training_states/dfbf73de-a3e3-48a6-841a-3e926031e249_TransformerPlusTemporal/checkpoint-12000/trainer_state.json',
#  './training_states/f8572cc1-c3a8-4c48-9fbd-546d50c91a47_TransformerLikeFu/checkpoint-60000/trainer_state.json',
#  './training_states/f8572cc1-c3a8-4c48-9fbd-546d50c91a47_TransformerLikeFu/checkpoint-40000/trainer_state.json',
#  './training_states/f8572cc1-c3a8-4c48-9fbd-546d50c91a47_TransformerLikeFu/checkpoint-20000/trainer_state.json',
#  './training_states/f8572cc1-c3a8-4c48-9fbd-546d50c91a47_TransformerLikeFu/checkpoint-80000/trainer_state.json',
#  './training_states/4d91f634-d378-4c09-9c2f-7e766073452e_TransformerPlusTemporal/checkpoint-8000/trainer_state.json',
#  './training_states/4d91f634-d378-4c09-9c2f-7e766073452e_TransformerPlusTemporal/checkpoint-6000/trainer_state.json',
#  './training_states/4d91f634-d378-4c09-9c2f-7e766073452e_TransformerPlusTemporal/checkpoint-5000/trainer_state.json',
#  './training_states/4d91f634-d378-4c09-9c2f-7e766073452e_TransformerPlusTemporal/checkpoint-7000/trainer_state.json',
#  './training_states/1f61ff31-6eba-45ea-a9b0-64e0a55e6417_TransformerLikeFu/checkpoint-60000/trainer_state.json',
#  './training_states/1f61ff31-6eba-45ea-a9b0-64e0a55e6417_TransformerLikeFu/checkpoint-40000/trainer_state.json',
#  './training_states/1f61ff31-6eba-45ea-a9b0-64e0a55e6417_TransformerLikeFu/checkpoint-100000/trainer_state.json',
#  './training_states/1f61ff31-6eba-45ea-a9b0-64e0a55e6417_TransformerLikeFu/checkpoint-80000/trainer_state.json',
#  './training_states/df827652-469e-47d7-8072-c15214b10cec_TransformerPlusTemporal/checkpoint-4000/trainer_state.json',
#  './training_states/df827652-469e-47d7-8072-c15214b10cec_TransformerPlusTemporal/checkpoint-2000/trainer_state.json',
#  './training_states/df827652-469e-47d7-8072-c15214b10cec_TransformerPlusTemporal/checkpoint-1000/trainer_state.json',
#  './training_states/df827652-469e-47d7-8072-c15214b10cec_TransformerPlusTemporal/checkpoint-3000/trainer_state.json',
#  './training_states/3d32b82c-8880-4cc6-8041-e51fe9e3ca2c_TransformerPlusTemporal/checkpoint-6000/trainer_state.json',
#  './training_states/3d32b82c-8880-4cc6-8041-e51fe9e3ca2c_TransformerPlusTemporal/checkpoint-9000/trainer_state.json',
#  './training_states/3d32b82c-8880-4cc6-8041-e51fe9e3ca2c_TransformerPlusTemporal/checkpoint-15000/trainer_state.json',
#  './training_states/3d32b82c-8880-4cc6-8041-e51fe9e3ca2c_TransformerPlusTemporal/checkpoint-12000/trainer_state.json',
#  './training_states/76218462-2f00-4650-8692-4456d2dfc7e9_TransformerPlusTemporal/checkpoint-8000/trainer_state.json',
#  './training_states/76218462-2f00-4650-8692-4456d2dfc7e9_TransformerPlusTemporal/checkpoint-6000/trainer_state.json',
#  './training_states/76218462-2f00-4650-8692-4456d2dfc7e9_TransformerPlusTemporal/checkpoint-9000/trainer_state.json',
#  './training_states/76218462-2f00-4650-8692-4456d2dfc7e9_TransformerPlusTemporal/checkpoint-7000/trainer_state.json']

# %%
test_results = {
    "Roberta-likeFu": {"hash": "6184d3d8-3de9-4b16-b11d-7f7bd8ec1821", "p": 0.67, "r": 0.24, "f": 0.36},
    "TLB-500-likeFu": {"hash": "1f61ff31-6eba-45ea-a9b0-64e0a55e6417", "p": 0.97, "r": 0.11, "f": 0.20},
    "TLB-1000-likeFu": {"hash": "f8572cc1-c3a8-4c48-9fbd-546d50c91a47", "p": 0.84,"r": 0.13,"f": 0.22},
    "Roberta-plusTemporal": {"hash": "3bfa095a-7fe5-42aa-8d89-e780c3933abb", "p": 1.0, "r": 0.15, "f": 0.26},
    "TLB-500-plusTemporal": {"hash": "3d32b82c-8880-4cc6-8041-e51fe9e3ca2c", "p": 1.0, "r": 0.15, "f": 0.26},
    "TLB-1000-plusTemporal": {"hash": "dfbf73de-a3e3-48a6-841a-3e926031e249", "p": 1.0, "r": 0.15, "f": 0.26}
}

# %%
training_data = []
for name, t in test_results.items():
    training_files = {fn.split("/")[-2].split("-")[-1]: fn for fn in f_names if t["hash"] in fn}
    mx_trf = max(training_files.keys())
    d = {"name": name,
         "training_file": training_files[mx_trf]}
    d.update(t)
    training_data.append(d)

# %%
training_data
# Out:
# [{'name': 'Roberta-likeFu',
#   'training_file': './training_states/6184d3d8-3de9-4b16-b11d-7f7bd8ec1821_TransformerPlusTemporal/checkpoint-80000/trainer_state.json',
#   'hash': '6184d3d8-3de9-4b16-b11d-7f7bd8ec1821',
#   'p': 0.67,
#   'r': 0.24,
#   'f': 0.36},
#  {'name': 'TLB-500-likeFu',
#   'training_file': './training_states/1f61ff31-6eba-45ea-a9b0-64e0a55e6417_TransformerLikeFu/checkpoint-80000/trainer_state.json',
#   'hash': '1f61ff31-6eba-45ea-a9b0-64e0a55e6417',
#   'p': 0.97,
#   'r': 0.11,
#   'f': 0.2},
#  {'name': 'TLB-1000-likeFu',
#   'training_file': './training_states/f8572cc1-c3a8-4c48-9fbd-546d50c91a47_TransformerLikeFu/checkpoint-80000/trainer_state.json',
#   'hash': 'f8572cc1-c3a8-4c48-9fbd-546d50c91a47',
#   'p': 0.84,
#   'r': 0.13,
#   'f': 0.22},
#  {'name': 'Roberta-plusTemporal',
#   'training_file': './training_states/3bfa095a-7fe5-42aa-8d89-e780c3933abb_TransformerPlusTemporal/checkpoint-9000/trainer_state.json',
#   'hash': '3bfa095a-7fe5-42aa-8d89-e780c3933abb',
#   'p': 1.0,
#   'r': 0.15,
#   'f': 0.26},
#  {'name': 'TLB-500-plusTemporal',
#   'training_file': './training_states/3d32b82c-8880-4cc6-8041-e51fe9e3ca2c_TransformerPlusTemporal/checkpoint-9000/trainer_state.json',
#   'hash': '3d32b82c-8880-4cc6-8041-e51fe9e3ca2c',
#   'p': 1.0,
#   'r': 0.15,
#   'f': 0.26},
#  {'name': 'TLB-1000-plusTemporal',
#   'training_file': './training_states/dfbf73de-a3e3-48a6-841a-3e926031e249_TransformerPlusTemporal/checkpoint-9000/trainer_state.json',
#   'hash': 'dfbf73de-a3e3-48a6-841a-3e926031e249',
#   'p': 1.0,
#   'r': 0.15,
#   'f': 0.26}]

# %%
# Build App
app = JupyterDash(__name__)
# Create server variable with Flask server object for use with gunicorn
server = app.server

app.layout = html.Div([
    html.H1("Model training progress"),
    # graph component
    dcc.Graph(id='graph'),
    html.Label([
        "choose model training checkpoint",
        dcc.Dropdown(
            id='model-select', clearable=False,
            value=training_data[0]["hash"], options=[{'label': d["name"], 'value': d["hash"]} for d in training_data])
    ]),
       # output evaluation metrics
    html.Div([
        "Evaluation on test set",
        html.Div(id="results")
    ])

])

# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    Output('results', 'children'),
    [Input("model-select", "value")]
)
def update_figure(run_hash):
    # check which component triggered the update    
    """
    x = list(range(len(hl_msg_data[match1]["msg_dens"][::scale])))
    msg_dens = hl_msg_data[match1]["msg_dens"][::scale]
    spp = ScipyPeaks(**ssp_params).predict(msg_dens)
    """

    tr_dat = [td for td in training_data if td["hash"] == run_hash][0]
    
    with open(tr_dat["training_file"], "r") as in_file:
        data = json.load(in_file)
    
    epochs_train = [elm["epoch"] for elm in data["log_history"] if "loss" in elm]
    loss_train = [elm["loss"] for elm in data["log_history"] if "loss" in elm]
    
    epochs_val = [elm["epoch"] for elm in data["log_history"] if "eval_loss" in elm]
    loss_val = [elm["eval_loss"] for elm in data["log_history"] if "eval_loss" in elm]
    f1_val = [elm["eval_f1"] for elm in data["log_history"] if "eval_loss" in elm]

    fig = go.Figure()
    fig.add_trace(go.Scatter(x=epochs_train, y=loss_train,
                        mode='lines',
                        name='training loss'))
    
    fig.add_trace(go.Scatter(x=epochs_val, y=loss_val,
                        mode='lines',
                        name='validation loss'))
    
    fig.add_trace(go.Scatter(x=epochs_val, y=f1_val,
                        mode='lines',
                        name='vaildation f1'))
    
    eval_result = html.Table([
                    html.Tr([html.Th('Precision'),
                             html.Th('Recall'),
                             html.Th('F-score'),
                             #html.Th('Accuracy')
                            ]),
                    html.Tr([html.Td("{:.5f}".format(tr_dat["p"])),
                             html.Td("{:.5f}".format(tr_dat["r"])),
                             html.Td("{:.5f}".format(tr_dat["f"])),
                             #html.Td("{:.5f}".format(evaluation["accuracy"]))
                            ])
    ])
    
    return fig, eval_result

# %%
# Run app and display result inline in the notebook
app.run_server(mode='jupyterlab')
# Out:
# /home/max/miniconda3/envs/chat-highlight-detection/lib/python3.8/site-packages/jupyter_dash/jupyter_app.py:139: UserWarning:
#
# The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.

# %%
with open("./training_states/1f61ff31-6eba-45ea-a9b0-64e0a55e6417_TransformerLikeFu/checkpoint-80000/trainer_state.json", "r") as in_file:
    data = json.load(in_file)

# %%
data["log_history"]
# Out:
# [{'epoch': 0.01,
#   'learning_rate': 1.9973901923428246e-05,
#   'loss': 0.1753,
#   'step': 500},
#  {'epoch': 0.03,
#   'learning_rate': 1.9947803846856487e-05,
#   'loss': 0.1542,
#   'step': 1000},
#  {'epoch': 0.04,
#   'learning_rate': 1.992170577028473e-05,
#   'loss': 0.1456,
#   'step': 1500},
#  {'epoch': 0.05,
#   'learning_rate': 1.9895607693712976e-05,
#   'loss': 0.1336,
#   'step': 2000},
#  {'epoch': 0.07,
#   'learning_rate': 1.9869509617141217e-05,
#   'loss': 0.1283,
#   'step': 2500},
#  {'epoch': 0.08,
#   'learning_rate': 1.984341154056946e-05,
#   'loss': 0.1222,
#   'step': 3000},
#  {'epoch': 0.09,
#   'learning_rate': 1.9817313463997706e-05,
#   'loss': 0.1197,
#   'step': 3500},
#  {'epoch': 0.1,
#   'learning_rate': 1.9791215387425947e-05,
#   'loss': 0.1123,
#   'step': 4000},
#  {'epoch': 0.12,
#   'learning_rate': 1.976511731085419e-05,
#   'loss': 0.1139,
#   'step': 4500},
#  {'epoch': 0.13,
#   'learning_rate': 1.9739019234282436e-05,
#   'loss': 0.1004,
#   'step': 5000},
#  {'epoch': 0.14,
#   'learning_rate': 1.9712921157710677e-05,
#   'loss': 0.098,
#   'step': 5500},
#  {'epoch': 0.16,
#   'learning_rate': 1.968682308113892e-05,
#   'loss': 0.096,
#   'step': 6000},
#  {'epoch': 0.17,
#   'learning_rate': 1.9660725004567166e-05,
#   'loss': 0.0917,
#   'step': 6500},
#  {'epoch': 0.18,
#   'learning_rate': 1.9634626927995407e-05,
#   'loss': 0.0872,
#   'step': 7000},
#  {'epoch': 0.2,
#   'learning_rate': 1.960852885142365e-05,
#   'loss': 0.0869,
#   'step': 7500},
#  {'epoch': 0.21,
#   'learning_rate': 1.9582430774851896e-05,
#   'loss': 0.0807,
#   'step': 8000},
#  {'epoch': 0.22,
#   'learning_rate': 1.9556332698280137e-05,
#   'loss': 0.0766,
#   'step': 8500},
#  {'epoch': 0.23,
#   'learning_rate': 1.953023462170838e-05,
#   'loss': 0.0758,
#   'step': 9000},
#  {'epoch': 0.25,
#   'learning_rate': 1.9504136545136626e-05,
#   'loss': 0.07,
#   'step': 9500},
#  {'epoch': 0.26,
#   'learning_rate': 1.9478038468564867e-05,
#   'loss': 0.07,
#   'step': 10000},
#  {'epoch': 0.27,
#   'learning_rate': 1.945194039199311e-05,
#   'loss': 0.0677,
#   'step': 10500},
#  {'epoch': 0.29,
#   'learning_rate': 1.9425842315421356e-05,
#   'loss': 0.065,
#   'step': 11000},
#  {'epoch': 0.3,
#   'learning_rate': 1.9399744238849597e-05,
#   'loss': 0.065,
#   'step': 11500},
#  {'epoch': 0.31,
#   'learning_rate': 1.937364616227784e-05,
#   'loss': 0.0632,
#   'step': 12000},
#  {'epoch': 0.33,
#   'learning_rate': 1.9347548085706085e-05,
#   'loss': 0.0595,
#   'step': 12500},
#  {'epoch': 0.34,
#   'learning_rate': 1.9321450009134327e-05,
#   'loss': 0.0601,
#   'step': 13000},
#  {'epoch': 0.35,
#   'learning_rate': 1.929535193256257e-05,
#   'loss': 0.0603,
#   'step': 13500},
#  {'epoch': 0.37,
#   'learning_rate': 1.9269253855990815e-05,
#   'loss': 0.054,
#   'step': 14000},
#  {'epoch': 0.38,
#   'learning_rate': 1.924315577941906e-05,
#   'loss': 0.055,
#   'step': 14500},
#  {'epoch': 0.39,
#   'learning_rate': 1.92170577028473e-05,
#   'loss': 0.0538,
#   'step': 15000},
#  {'epoch': 0.4,
#   'learning_rate': 1.9190959626275545e-05,
#   'loss': 0.0507,
#   'step': 15500},
#  {'epoch': 0.42,
#   'learning_rate': 1.916486154970379e-05,
#   'loss': 0.0513,
#   'step': 16000},
#  {'epoch': 0.43,
#   'learning_rate': 1.913876347313203e-05,
#   'loss': 0.0505,
#   'step': 16500},
#  {'epoch': 0.44,
#   'learning_rate': 1.9112665396560275e-05,
#   'loss': 0.0481,
#   'step': 17000},
#  {'epoch': 0.46,
#   'learning_rate': 1.908656731998852e-05,
#   'loss': 0.0451,
#   'step': 17500},
#  {'epoch': 0.47,
#   'learning_rate': 1.906046924341676e-05,
#   'loss': 0.0476,
#   'step': 18000},
#  {'epoch': 0.48,
#   'learning_rate': 1.9034371166845005e-05,
#   'loss': 0.0424,
#   'step': 18500},
#  {'epoch': 0.5,
#   'learning_rate': 1.900827309027325e-05,
#   'loss': 0.0432,
#   'step': 19000},
#  {'epoch': 0.51,
#   'learning_rate': 1.898217501370149e-05,
#   'loss': 0.0443,
#   'step': 19500},
#  {'epoch': 0.52,
#   'learning_rate': 1.8956076937129735e-05,
#   'loss': 0.0418,
#   'step': 20000},
#  {'epoch': 0.52,
#   'eval_f1': 0.47823683846897885,
#   'eval_loss': 0.12824174761772156,
#   'eval_precision': 0.3947533504419732,
#   'eval_recall': 0.6065013581004118,
#   'eval_runtime': 694.2178,
#   'eval_samples_per_second': 153.78,
#   'eval_steps_per_second': 9.612,
#   'step': 20000},
#  {'epoch': 0.54,
#   'learning_rate': 1.892997886055798e-05,
#   'loss': 0.0428,
#   'step': 20500},
#  {'epoch': 0.55,
#   'learning_rate': 1.890388078398622e-05,
#   'loss': 0.0407,
#   'step': 21000},
#  {'epoch': 0.56,
#   'learning_rate': 1.8877782707414465e-05,
#   'loss': 0.0404,
#   'step': 21500},
#  {'epoch': 0.57,
#   'learning_rate': 1.885168463084271e-05,
#   'loss': 0.0346,
#   'step': 22000},
#  {'epoch': 0.59,
#   'learning_rate': 1.882558655427095e-05,
#   'loss': 0.0405,
#   'step': 22500},
#  {'epoch': 0.6,
#   'learning_rate': 1.8799488477699195e-05,
#   'loss': 0.0377,
#   'step': 23000},
#  {'epoch': 0.61,
#   'learning_rate': 1.877339040112744e-05,
#   'loss': 0.0397,
#   'step': 23500},
#  {'epoch': 0.63,
#   'learning_rate': 1.874729232455568e-05,
#   'loss': 0.0408,
#   'step': 24000},
#  {'epoch': 0.64,
#   'learning_rate': 1.8721194247983925e-05,
#   'loss': 0.0376,
#   'step': 24500},
#  {'epoch': 0.65,
#   'learning_rate': 1.869509617141217e-05,
#   'loss': 0.0341,
#   'step': 25000},
#  {'epoch': 0.67,
#   'learning_rate': 1.866899809484041e-05,
#   'loss': 0.0354,
#   'step': 25500},
#  {'epoch': 0.68,
#   'learning_rate': 1.8642900018268655e-05,
#   'loss': 0.0366,
#   'step': 26000},
#  {'epoch': 0.69,
#   'learning_rate': 1.86168019416969e-05,
#   'loss': 0.0371,
#   'step': 26500},
#  {'epoch': 0.7,
#   'learning_rate': 1.859070386512514e-05,
#   'loss': 0.0348,
#   'step': 27000},
#  {'epoch': 0.72,
#   'learning_rate': 1.8564605788553385e-05,
#   'loss': 0.0323,
#   'step': 27500},
#  {'epoch': 0.73,
#   'learning_rate': 1.853850771198163e-05,
#   'loss': 0.0311,
#   'step': 28000},
#  {'epoch': 0.74,
#   'learning_rate': 1.851240963540987e-05,
#   'loss': 0.0331,
#   'step': 28500},
#  {'epoch': 0.76,
#   'learning_rate': 1.8486311558838115e-05,
#   'loss': 0.0283,
#   'step': 29000},
#  {'epoch': 0.77,
#   'learning_rate': 1.846021348226636e-05,
#   'loss': 0.0295,
#   'step': 29500},
#  {'epoch': 0.78,
#   'learning_rate': 1.84341154056946e-05,
#   'loss': 0.0307,
#   'step': 30000},
#  {'epoch': 0.8,
#   'learning_rate': 1.8408017329122845e-05,
#   'loss': 0.0294,
#   'step': 30500},
#  {'epoch': 0.81,
#   'learning_rate': 1.838191925255109e-05,
#   'loss': 0.0292,
#   'step': 31000},
#  {'epoch': 0.82,
#   'learning_rate': 1.835582117597933e-05,
#   'loss': 0.0322,
#   'step': 31500},
#  {'epoch': 0.84,
#   'learning_rate': 1.8329723099407575e-05,
#   'loss': 0.0288,
#   'step': 32000},
#  {'epoch': 0.85,
#   'learning_rate': 1.830362502283582e-05,
#   'loss': 0.0278,
#   'step': 32500},
#  {'epoch': 0.86,
#   'learning_rate': 1.827752694626406e-05,
#   'loss': 0.0231,
#   'step': 33000},
#  {'epoch': 0.87,
#   'learning_rate': 1.8251428869692304e-05,
#   'loss': 0.0283,
#   'step': 33500},
#  {'epoch': 0.89,
#   'learning_rate': 1.822533079312055e-05,
#   'loss': 0.0278,
#   'step': 34000},
#  {'epoch': 0.9,
#   'learning_rate': 1.819923271654879e-05,
#   'loss': 0.0249,
#   'step': 34500},
#  {'epoch': 0.91,
#   'learning_rate': 1.8173134639977034e-05,
#   'loss': 0.0246,
#   'step': 35000},
#  {'epoch': 0.93,
#   'learning_rate': 1.814703656340528e-05,
#   'loss': 0.0244,
#   'step': 35500},
#  {'epoch': 0.94,
#   'learning_rate': 1.812093848683352e-05,
#   'loss': 0.0272,
#   'step': 36000},
#  {'epoch': 0.95,
#   'learning_rate': 1.8094840410261764e-05,
#   'loss': 0.0245,
#   'step': 36500},
#  {'epoch': 0.97,
#   'learning_rate': 1.806874233369001e-05,
#   'loss': 0.0251,
#   'step': 37000},
#  {'epoch': 0.98,
#   'learning_rate': 1.804264425711825e-05,
#   'loss': 0.0259,
#   'step': 37500},
#  {'epoch': 0.99,
#   'learning_rate': 1.8016546180546494e-05,
#   'loss': 0.026,
#   'step': 38000},
#  {'epoch': 1.0,
#   'learning_rate': 1.799044810397474e-05,
#   'loss': 0.0238,
#   'step': 38500},
#  {'epoch': 1.02,
#   'learning_rate': 1.796435002740298e-05,
#   'loss': 0.0189,
#   'step': 39000},
#  {'epoch': 1.03,
#   'learning_rate': 1.7938251950831224e-05,
#   'loss': 0.0174,
#   'step': 39500},
#  {'epoch': 1.04,
#   'learning_rate': 1.791215387425947e-05,
#   'loss': 0.0211,
#   'step': 40000},
#  {'epoch': 1.04,
#   'eval_f1': 0.48798047085109025,
#   'eval_loss': 0.11112770438194275,
#   'eval_precision': 0.4622922546252744,
#   'eval_recall': 0.5166914921580653,
#   'eval_runtime': 691.8083,
#   'eval_samples_per_second': 154.316,
#   'eval_steps_per_second': 9.646,
#   'step': 40000},
#  {'epoch': 1.06,
#   'learning_rate': 1.7886055797687713e-05,
#   'loss': 0.0177,
#   'step': 40500},
#  {'epoch': 1.07,
#   'learning_rate': 1.7859957721115954e-05,
#   'loss': 0.0204,
#   'step': 41000},
#  {'epoch': 1.08,
#   'learning_rate': 1.78338596445442e-05,
#   'loss': 0.0179,
#   'step': 41500},
#  {'epoch': 1.1,
#   'learning_rate': 1.7807761567972443e-05,
#   'loss': 0.0171,
#   'step': 42000},
#  {'epoch': 1.11,
#   'learning_rate': 1.7781663491400684e-05,
#   'loss': 0.0155,
#   'step': 42500},
#  {'epoch': 1.12,
#   'learning_rate': 1.775556541482893e-05,
#   'loss': 0.0182,
#   'step': 43000},
#  {'epoch': 1.14,
#   'learning_rate': 1.7729467338257173e-05,
#   'loss': 0.0166,
#   'step': 43500},
#  {'epoch': 1.15,
#   'learning_rate': 1.7703369261685414e-05,
#   'loss': 0.0195,
#   'step': 44000},
#  {'epoch': 1.16,
#   'learning_rate': 1.767727118511366e-05,
#   'loss': 0.0171,
#   'step': 44500},
#  {'epoch': 1.17,
#   'learning_rate': 1.7651173108541903e-05,
#   'loss': 0.0189,
#   'step': 45000},
#  {'epoch': 1.19,
#   'learning_rate': 1.7625075031970144e-05,
#   'loss': 0.018,
#   'step': 45500},
#  {'epoch': 1.2,
#   'learning_rate': 1.759897695539839e-05,
#   'loss': 0.0174,
#   'step': 46000},
#  {'epoch': 1.21,
#   'learning_rate': 1.7572878878826633e-05,
#   'loss': 0.0168,
#   'step': 46500},
#  {'epoch': 1.23,
#   'learning_rate': 1.7546780802254874e-05,
#   'loss': 0.0181,
#   'step': 47000},
#  {'epoch': 1.24,
#   'learning_rate': 1.7520682725683118e-05,
#   'loss': 0.0163,
#   'step': 47500},
#  {'epoch': 1.25,
#   'learning_rate': 1.7494584649111363e-05,
#   'loss': 0.0166,
#   'step': 48000},
#  {'epoch': 1.27,
#   'learning_rate': 1.7468486572539604e-05,
#   'loss': 0.0197,
#   'step': 48500},
#  {'epoch': 1.28,
#   'learning_rate': 1.7442388495967848e-05,
#   'loss': 0.0154,
#   'step': 49000},
#  {'epoch': 1.29,
#   'learning_rate': 1.7416290419396093e-05,
#   'loss': 0.0178,
#   'step': 49500},
#  {'epoch': 1.3,
#   'learning_rate': 1.7390192342824334e-05,
#   'loss': 0.0158,
#   'step': 50000},
#  {'epoch': 1.32,
#   'learning_rate': 1.7364094266252578e-05,
#   'loss': 0.0157,
#   'step': 50500},
#  {'epoch': 1.33,
#   'learning_rate': 1.7337996189680823e-05,
#   'loss': 0.0161,
#   'step': 51000},
#  {'epoch': 1.34,
#   'learning_rate': 1.7311898113109064e-05,
#   'loss': 0.0173,
#   'step': 51500},
#  {'epoch': 1.36,
#   'learning_rate': 1.7285800036537308e-05,
#   'loss': 0.0146,
#   'step': 52000},
#  {'epoch': 1.37,
#   'learning_rate': 1.7259701959965552e-05,
#   'loss': 0.0147,
#   'step': 52500},
#  {'epoch': 1.38,
#   'learning_rate': 1.7233603883393794e-05,
#   'loss': 0.0151,
#   'step': 53000},
#  {'epoch': 1.4,
#   'learning_rate': 1.7207505806822038e-05,
#   'loss': 0.0143,
#   'step': 53500},
#  {'epoch': 1.41,
#   'learning_rate': 1.7181407730250282e-05,
#   'loss': 0.0164,
#   'step': 54000},
#  {'epoch': 1.42,
#   'learning_rate': 1.7155309653678523e-05,
#   'loss': 0.0163,
#   'step': 54500},
#  {'epoch': 1.44,
#   'learning_rate': 1.7129211577106768e-05,
#   'loss': 0.0144,
#   'step': 55000},
#  {'epoch': 1.45,
#   'learning_rate': 1.7103113500535012e-05,
#   'loss': 0.0165,
#   'step': 55500},
#  {'epoch': 1.46,
#   'learning_rate': 1.7077015423963253e-05,
#   'loss': 0.0139,
#   'step': 56000},
#  {'epoch': 1.47,
#   'learning_rate': 1.7050917347391498e-05,
#   'loss': 0.0159,
#   'step': 56500},
#  {'epoch': 1.49,
#   'learning_rate': 1.7024819270819742e-05,
#   'loss': 0.0155,
#   'step': 57000},
#  {'epoch': 1.5,
#   'learning_rate': 1.6998721194247983e-05,
#   'loss': 0.0142,
#   'step': 57500},
#  {'epoch': 1.51,
#   'learning_rate': 1.6972623117676228e-05,
#   'loss': 0.0157,
#   'step': 58000},
#  {'epoch': 1.53,
#   'learning_rate': 1.6946525041104472e-05,
#   'loss': 0.0146,
#   'step': 58500},
#  {'epoch': 1.54,
#   'learning_rate': 1.6920426964532713e-05,
#   'loss': 0.0136,
#   'step': 59000},
#  {'epoch': 1.55,
#   'learning_rate': 1.6894328887960958e-05,
#   'loss': 0.0125,
#   'step': 59500},
#  {'epoch': 1.57,
#   'learning_rate': 1.6868230811389202e-05,
#   'loss': 0.0151,
#   'step': 60000},
#  {'epoch': 1.57,
#   'eval_f1': 0.446306641837368,
#   'eval_loss': 0.11278606951236725,
#   'eval_precision': 0.45175477964276095,
#   'eval_recall': 0.4409883466222728,
#   'eval_runtime': 692.0455,
#   'eval_samples_per_second': 154.263,
#   'eval_steps_per_second': 9.642,
#   'step': 60000},
#  {'epoch': 1.58,
#   'learning_rate': 1.6842132734817443e-05,
#   'loss': 0.0133,
#   'step': 60500},
#  {'epoch': 1.59,
#   'learning_rate': 1.6816034658245688e-05,
#   'loss': 0.0132,
#   'step': 61000},
#  {'epoch': 1.61,
#   'learning_rate': 1.6789936581673932e-05,
#   'loss': 0.015,
#   'step': 61500},
#  {'epoch': 1.62,
#   'learning_rate': 1.6763838505102173e-05,
#   'loss': 0.014,
#   'step': 62000},
#  {'epoch': 1.63,
#   'learning_rate': 1.6737740428530418e-05,
#   'loss': 0.0132,
#   'step': 62500},
#  {'epoch': 1.64,
#   'learning_rate': 1.6711642351958662e-05,
#   'loss': 0.0133,
#   'step': 63000},
#  {'epoch': 1.66,
#   'learning_rate': 1.6685544275386903e-05,
#   'loss': 0.0145,
#   'step': 63500},
#  {'epoch': 1.67,
#   'learning_rate': 1.6659446198815147e-05,
#   'loss': 0.0125,
#   'step': 64000},
#  {'epoch': 1.68,
#   'learning_rate': 1.6633348122243392e-05,
#   'loss': 0.0118,
#   'step': 64500},
#  {'epoch': 1.7,
#   'learning_rate': 1.6607250045671633e-05,
#   'loss': 0.0134,
#   'step': 65000},
#  {'epoch': 1.71,
#   'learning_rate': 1.6581151969099877e-05,
#   'loss': 0.0135,
#   'step': 65500},
#  {'epoch': 1.72,
#   'learning_rate': 1.6555053892528122e-05,
#   'loss': 0.0144,
#   'step': 66000},
#  {'epoch': 1.74,
#   'learning_rate': 1.6528955815956366e-05,
#   'loss': 0.0131,
#   'step': 66500},
#  {'epoch': 1.75,
#   'learning_rate': 1.6502857739384607e-05,
#   'loss': 0.0124,
#   'step': 67000},
#  {'epoch': 1.76,
#   'learning_rate': 1.6476759662812852e-05,
#   'loss': 0.0117,
#   'step': 67500},
#  {'epoch': 1.77,
#   'learning_rate': 1.6450661586241096e-05,
#   'loss': 0.0138,
#   'step': 68000},
#  {'epoch': 1.79,
#   'learning_rate': 1.6424563509669337e-05,
#   'loss': 0.0117,
#   'step': 68500},
#  {'epoch': 1.8,
#   'learning_rate': 1.639846543309758e-05,
#   'loss': 0.0129,
#   'step': 69000},
#  {'epoch': 1.81,
#   'learning_rate': 1.6372367356525826e-05,
#   'loss': 0.0133,
#   'step': 69500},
#  {'epoch': 1.83,
#   'learning_rate': 1.6346269279954067e-05,
#   'loss': 0.011,
#   'step': 70000},
#  {'epoch': 1.84,
#   'learning_rate': 1.632017120338231e-05,
#   'loss': 0.0113,
#   'step': 70500},
#  {'epoch': 1.85,
#   'learning_rate': 1.6294073126810556e-05,
#   'loss': 0.0126,
#   'step': 71000},
#  {'epoch': 1.87,
#   'learning_rate': 1.6267975050238797e-05,
#   'loss': 0.012,
#   'step': 71500},
#  {'epoch': 1.88,
#   'learning_rate': 1.624187697366704e-05,
#   'loss': 0.0126,
#   'step': 72000},
#  {'epoch': 1.89,
#   'learning_rate': 1.6215778897095286e-05,
#   'loss': 0.0118,
#   'step': 72500},
#  {'epoch': 1.91,
#   'learning_rate': 1.6189680820523527e-05,
#   'loss': 0.0135,
#   'step': 73000},
#  {'epoch': 1.92,
#   'learning_rate': 1.616358274395177e-05,
#   'loss': 0.0136,
#   'step': 73500},
#  {'epoch': 1.93,
#   'learning_rate': 1.6137484667380016e-05,
#   'loss': 0.0116,
#   'step': 74000},
#  {'epoch': 1.94,
#   'learning_rate': 1.6111386590808257e-05,
#   'loss': 0.0114,
#   'step': 74500},
#  {'epoch': 1.96,
#   'learning_rate': 1.60852885142365e-05,
#   'loss': 0.0128,
#   'step': 75000},
#  {'epoch': 1.97,
#   'learning_rate': 1.6059190437664746e-05,
#   'loss': 0.0113,
#   'step': 75500},
#  {'epoch': 1.98,
#   'learning_rate': 1.6033092361092987e-05,
#   'loss': 0.0106,
#   'step': 76000},
#  {'epoch': 2.0,
#   'learning_rate': 1.600699428452123e-05,
#   'loss': 0.0115,
#   'step': 76500},
#  {'epoch': 2.01,
#   'learning_rate': 1.5980896207949476e-05,
#   'loss': 0.0091,
#   'step': 77000},
#  {'epoch': 2.02,
#   'learning_rate': 1.5954798131377717e-05,
#   'loss': 0.0083,
#   'step': 77500},
#  {'epoch': 2.04,
#   'learning_rate': 1.592870005480596e-05,
#   'loss': 0.0087,
#   'step': 78000},
#  {'epoch': 2.05,
#   'learning_rate': 1.5902601978234206e-05,
#   'loss': 0.0089,
#   'step': 78500},
#  {'epoch': 2.06,
#   'learning_rate': 1.5876503901662447e-05,
#   'loss': 0.0104,
#   'step': 79000},
#  {'epoch': 2.07,
#   'learning_rate': 1.585040582509069e-05,
#   'loss': 0.0079,
#   'step': 79500},
#  {'epoch': 2.09,
#   'learning_rate': 1.5824307748518936e-05,
#   'loss': 0.0097,
#   'step': 80000},
#  {'epoch': 2.09,
#   'eval_f1': 0.44891137013415433,
#   'eval_loss': 0.11575652658939362,
#   'eval_precision': 0.4507154213036566,
#   'eval_recall': 0.44712170332077456,
#   'eval_runtime': 692.3033,
#   'eval_samples_per_second': 154.206,
#   'eval_steps_per_second': 9.639,
#   'step': 80000}]

# %%
[elm["epoch"] for elm in data["log_history"] if "loss" in elm]
[elm["loss"] for elm in data["log_history"] if "loss" in elm]
# Out:
# [0.1753,
#  0.1542,
#  0.1456,
#  0.1336,
#  0.1283,
#  0.1222,
#  0.1197,
#  0.1123,
#  0.1139,
#  0.1004,
#  0.098,
#  0.096,
#  0.0917,
#  0.0872,
#  0.0869,
#  0.0807,
#  0.0766,
#  0.0758,
#  0.07,
#  0.07,
#  0.0677,
#  0.065,
#  0.065,
#  0.0632,
#  0.0595,
#  0.0601,
#  0.0603,
#  0.054,
#  0.055,
#  0.0538,
#  0.0507,
#  0.0513,
#  0.0505,
#  0.0481,
#  0.0451,
#  0.0476,
#  0.0424,
#  0.0432,
#  0.0443,
#  0.0418,
#  0.0428,
#  0.0407,
#  0.0404,
#  0.0346,
#  0.0405,
#  0.0377,
#  0.0397,
#  0.0408,
#  0.0376,
#  0.0341,
#  0.0354,
#  0.0366,
#  0.0371,
#  0.0348,
#  0.0323,
#  0.0311,
#  0.0331,
#  0.0283,
#  0.0295,
#  0.0307,
#  0.0294,
#  0.0292,
#  0.0322,
#  0.0288,
#  0.0278,
#  0.0231,
#  0.0283,
#  0.0278,
#  0.0249,
#  0.0246,
#  0.0244,
#  0.0272,
#  0.0245,
#  0.0251,
#  0.0259,
#  0.026,
#  0.0238,
#  0.0189,
#  0.0174,
#  0.0211,
#  0.0177,
#  0.0204,
#  0.0179,
#  0.0171,
#  0.0155,
#  0.0182,
#  0.0166,
#  0.0195,
#  0.0171,
#  0.0189,
#  0.018,
#  0.0174,
#  0.0168,
#  0.0181,
#  0.0163,
#  0.0166,
#  0.0197,
#  0.0154,
#  0.0178,
#  0.0158,
#  0.0157,
#  0.0161,
#  0.0173,
#  0.0146,
#  0.0147,
#  0.0151,
#  0.0143,
#  0.0164,
#  0.0163,
#  0.0144,
#  0.0165,
#  0.0139,
#  0.0159,
#  0.0155,
#  0.0142,
#  0.0157,
#  0.0146,
#  0.0136,
#  0.0125,
#  0.0151,
#  0.0133,
#  0.0132,
#  0.015,
#  0.014,
#  0.0132,
#  0.0133,
#  0.0145,
#  0.0125,
#  0.0118,
#  0.0134,
#  0.0135,
#  0.0144,
#  0.0131,
#  0.0124,
#  0.0117,
#  0.0138,
#  0.0117,
#  0.0129,
#  0.0133,
#  0.011,
#  0.0113,
#  0.0126,
#  0.012,
#  0.0126,
#  0.0118,
#  0.0135,
#  0.0136,
#  0.0116,
#  0.0114,
#  0.0128,
#  0.0113,
#  0.0106,
#  0.0115,
#  0.0091,
#  0.0083,
#  0.0087,
#  0.0089,
#  0.0104,
#  0.0079,
#  0.0097]
