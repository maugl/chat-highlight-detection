# %% [markdown]
# ## Setup

# %% [markdown]
# ### VM setup

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/MyDrive/Master Thesis/Language Model Training"
# Out:
# /content/gdrive/MyDrive/Master Thesis/Language Model Training

# %%
# !pip install transformers==4.18
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers==4.18 in /usr/local/lib/python3.7/dist-packages (4.18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (21.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (0.0.53)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (3.8.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (0.12.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (4.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (0.8.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.18) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.18) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.18) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.18) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.18) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.18) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.18) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.18) (2022.6.15)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.18) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.18) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.18) (7.1.2)

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.8.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %% [markdown]
# use MLM scoring from: https://github.com/awslabs/mlm-scoring
# => version incompatibility

# %% [markdown]
# ### Imports

# %%
from pathlib import Path
import random
import torch

from copy import deepcopy

import transformers
from transformers import LineByLineTextDataset
from transformers import DataCollatorForLanguageModeling
from transformers import RobertaTokenizerFast
from transformers import RobertaForMaskedLM
from transformers import FillMaskPipeline
from transformers import TrainingArguments, Trainer

import datasets
from datasets import load_dataset

from tokenizers import ByteLevelBPETokenizer

import numpy as np

import glob
import json

# %% [markdown]
# ## Loading components

# %% [markdown]
# ### Load Data

# %%
dataset = load_dataset('text', data_files={'train': "data/twitch_lol_combined.txt"})
# Out:
# WARNING:datasets.builder:Using custom data configuration default-83f6c26edc6ac600
# Downloading and preparing dataset text/default to /root/.cache/huggingface/datasets/text/default-83f6c26edc6ac600/0.0.0/21a506d1b2b34316b1e82d0bd79066905d846e5d7e619823c0dd338d6f1fa6ad...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-83f6c26edc6ac600/0.0.0/21a506d1b2b34316b1e82d0bd79066905d846e5d7e619823c0dd338d6f1fa6ad. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# arbitrary split of 10%, same as in training validation, but  seed this time (some examples may overlap)
ds_split = dataset["train"].train_test_split(test_size=0.1, seed=42069)

# %%
ds_split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 80076419
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 8897380
#     })
# })

# %% [markdown]
# ### Load Tokenizer

# %%
tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")
# Out:
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %% [markdown]
# ### Load Model

# %%
model = RobertaForMaskedLM.from_pretrained("roberta-base")
# Out:
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]

# %% [markdown]
# ### Create DataCollator

# %%
data_collator = DataCollatorForLanguageModeling(
  tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)

# %% [markdown]
# ### Load val dataset from disk

# %%
ds_val_grouped = datasets.load_from_disk("./data/initial_mlm_test_data_roberta/")

# %%
ds_val_grouped_sharded = ds_val_grouped.shard(100,index=0)
ds_val_grouped_sharded
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'special_tokens_mask', 'labels'],
#     num_rows: 7205
# })

# %% [markdown]
# ### Load Pipeline for mask filling

# %%
mask_pipe = FillMaskPipeline(model, tokenizer)

# %% [markdown]
# ### Tokenize validation set

# %%
def tokenize_function(examples):
  # using return_special_tokens_mask=True for optimized DataCollator later
  return tokenizer(examples["text"], return_special_tokens_mask=True)

def group_texts(examples, tokenizer, block_size=128):
    """
    :param tokenizer:
    :param examples: DatasetDict containing fields with iterables to group
    :param block_size: maximum size of each group in items (tokens)

    :return: Each entry of examples grouped to block_size (number of tokens)
    """
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])

    # keep remainder to add on later
    remainder = total_length % block_size
    total_length = (total_length // block_size) * block_size
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    # add remaining tokens
    if remainder > 0:
        for k in concatenated_examples.keys():
            if k == "input_ids":
                result[k].append(concatenated_examples[k][-remainder:] + ([tokenizer.pad_token_id] * (block_size-remainder)))
            else:
                result[k].append(concatenated_examples[k][-remainder:] + ([type(concatenated_examples[k][0])()] * (block_size-remainder)))

    result["labels"] = result["input_ids"].copy()
    return result

# %%
ds_val_tok = ds_split["test"].map(tokenize_function, batched=True, num_proc=2, remove_columns=["text"])
# Out:
# #1:   0%|          | 0/4449 [00:00<?, ?ba/s]
# #0:   0%|          | 0/4449 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (514 > 512). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (515 > 512). Running this sequence through the model will result in indexing errors

# %%
ds_val_grouped = ds_val_tok.map(
        group_texts,
        fn_kwargs={"tokenizer": tokenizer},
        batched=True,
        batch_size=1000,
        num_proc=2
    )
# Out:
# #0:   0%|          | 0/4449 [00:00<?, ?ba/s]
# #1:   0%|          | 0/4449 [00:00<?, ?ba/s]

# %%
# save dataset
ds_val_grouped.save_to_disk("./data/initial_mlm_test_data_roberta")

# %% [markdown]
# ### Mask filling

# %%
def batch_fill_mask(batch):
  # encode batch into input_ids and attention_mask with padding
  batch_encoded = tokenizer.batch_encode_plus(batch, truncation=True, padding=True, max_length=128)
  # transform to a list that the data collator can read and mask
  batch_encoded_list = [dict(zip(batch_encoded, t)) for t in zip(*batch_encoded.values())]
  batch_masked = data_collator(batch_encoded_list)
  # decode again to show masked clear text and feed into mask filling pipeline
  batch_masked_strings = tokenizer.batch_decode(batch_masked["input_ids"])

  best_examples = list()
  for example in batch_masked_strings:
    if not "<mask>" in example:
      # hacky solution which loses some examples
      # for future implement my own masking startegy
      continue
    example = mask_pipe(example[3:-3]) # for stripping <s> and </s>
    best_score_res = list()
    for mask in example:
      if type(mask) is not list:
        mask = [mask]
      best_score_res.append(sorted(mask, key=lambda x: x["score"])[-1])
      best_examples.append(best_score_res)
  
  for orig, masked, predictions in zip(batch, batch_masked_strings, best_examples):
    unmasked = deepcopy(masked)
    for res in predictions:
      unmasked = unmasked.replace("<mask>", res["token_str"], 1)
    yield {"orig": orig,
           "mask": masked,
           "pred": unmasked
           }

# %% [markdown]
# ## Some example predictions

# %% [markdown]
# ### Imaginary examples

# %%
mask_pipe(["LUL this is <mask>."])awesome, interesting, great, cool, bad
# Out:
# [{'score': 0.06589065492153168,
#   'token': 6344,
#   'token_str': ' awesome',
#   'sequence': 'LUL this is awesome.'},
#  {'score': 0.04585752636194229,
#   'token': 2679,
#   'token_str': ' interesting',
#   'sequence': 'LUL this is interesting.'},
#  {'score': 0.04143474996089935,
#   'token': 372,
#   'token_str': ' great',
#   'sequence': 'LUL this is great.'},
#  {'score': 0.03511602059006691,
#   'token': 3035,
#   'token_str': ' cool',
#   'sequence': 'LUL this is cool.'},
#  {'score': 0.02795984223484993,
#   'token': 1099,
#   'token_str': ' bad',
#   'sequence': 'LUL this is bad.'}]

# %%
mask_pipe(["ResidentSleeper this is <mask>."])
# Out:
# [{'score': 0.02327459119260311,
#   'token': 45,
#   'token_str': ' not',
#   'sequence': 'ResidentSleeper this is not.'},
#  {'score': 0.020932184532284737,
#   'token': 162,
#   'token_str': ' me',
#   'sequence': 'ResidentSleeper this is me.'},
#  {'score': 0.01878264546394348,
#   'token': 357,
#   'token_str': ' better',
#   'sequence': 'ResidentSleeper this is better.'},
#  {'score': 0.018267618492245674,
#   'token': 205,
#   'token_str': ' good',
#   'sequence': 'ResidentSleeper this is good.'},
#  {'score': 0.01669934019446373,
#   'token': 13,
#   'token_str': ' for',
#   'sequence': 'ResidentSleeper this is for.'}]

# %%
mask_pipe(["WutFace this is <mask>."])
# Out:
# [{'score': 0.09738326072692871,
#   'token': 6344,
#   'token_str': ' awesome',
#   'sequence': 'WutFace this is awesome.'},
#  {'score': 0.051141783595085144,
#   'token': 372,
#   'token_str': ' great',
#   'sequence': 'WutFace this is great.'},
#  {'score': 0.033073633909225464,
#   'token': 162,
#   'token_str': ' me',
#   'sequence': 'WutFace this is me.'},
#  {'score': 0.03268173709511757,
#   'token': 2679,
#   'token_str': ' interesting',
#   'sequence': 'WutFace this is interesting.'},
#  {'score': 0.031207386404275894,
#   'token': 14598,
#   'token_str': ' hilarious',
#   'sequence': 'WutFace this is hilarious.'}]

# %%
mask_pipe(["NotLikeThis this is <mask>."])
# Out:
# [{'score': 0.23756493628025055,
#   'token': 940,
#   'token_str': ' private',
#   'sequence': 'NotLikeThis this is private.'},
#  {'score': 0.13200481235980988,
#   'token': 14073,
#   'token_str': ' experimental',
#   'sequence': 'NotLikeThis this is experimental.'},
#  {'score': 0.10492823272943497,
#   'token': 18434,
#   'token_str': ' JavaScript',
#   'sequence': 'NotLikeThis this is JavaScript.'},
#  {'score': 0.056252479553222656,
#   'token': 1081,
#   'token_str': ' personal',
#   'sequence': 'NotLikeThis this is personal.'},
#  {'score': 0.04139917716383934,
#   'token': 10813,
#   'token_str': ' interactive',
#   'sequence': 'NotLikeThis this is interactive.'}]

# %%
mask_pipe(["THE BEST IS <mask> AND THE OTHERS"])
# Out:
# [{'score': 0.7594372034072876,
#   'token': 3779,
#   'token_str': ' IT',
#   'sequence': 'THE BEST IS IT AND THE OTHERS'},
#  {'score': 0.02422250807285309,
#   'token': 23435,
#   'token_str': ' BEST',
#   'sequence': 'THE BEST IS BEST AND THE OTHERS'},
#  {'score': 0.022127950564026833,
#   'token': 382,
#   'token_str': ' US',
#   'sequence': 'THE BEST IS US AND THE OTHERS'},
#  {'score': 0.017808886244893074,
#   'token': 10652,
#   'token_str': ' THIS',
#   'sequence': 'THE BEST IS THIS AND THE OTHERS'},
#  {'score': 0.016839774325489998,
#   'token': 9443,
#   'token_str': ' HERE',
#   'sequence': 'THE BEST IS HERE AND THE OTHERS'}]

# %%
mask_pipe(["NA <mask> EU"], )
# Out:
# [{'score': 0.44674187898635864,
#   'token': 846,
#   'token_str': 'V',
#   'sequence': 'NAV EU'},
#  {'score': 0.11876197904348373,
#   'token': 33520,
#   'token_str': 'WAY',
#   'sequence': 'NAWAY EU'},
#  {'score': 0.06054440885782242,
#   'token': 30876,
#   'token_str': 'BLE',
#   'sequence': 'NABLE EU'},
#  {'score': 0.05484357103705406,
#   'token': 387,
#   'token_str': 'B',
#   'sequence': 'NAB EU'},
#  {'score': 0.032075632363557816,
#   'token': 771,
#   'token_str': 'W',
#   'sequence': 'NAW EU'}]

# %%
mask_pipe(["LUL mods are trying to ban us <mask>"])
# Out:
# [{'score': 0.38371285796165466,
#   'token': 4,
#   'token_str': '.',
#   'sequence': 'LUL mods are trying to ban us.'},
#  {'score': 0.2154664397239685,
#   'token': 328,
#   'token_str': '!',
#   'sequence': 'LUL mods are trying to ban us!'},
#  {'score': 0.1222674772143364,
#   'token': 35,
#   'token_str': ':',
#   'sequence': 'LUL mods are trying to ban us:'},
#  {'score': 0.053981341421604156,
#   'token': 122,
#   'token_str': ' now',
#   'sequence': 'LUL mods are trying to ban us now'},
#  {'score': 0.022417498752474785,
#   'token': 6000,
#   'token_str': ' forever',
#   'sequence': 'LUL mods are trying to ban us forever'}]

# %% [markdown]
# ### Examples from training dataset

# %%
sample_range = 10


batch = list()
batch_inds = list()
for i in range(10):
  random.seed(i*22)
  sample_ind = random.randint(0, dataset["train"].num_rows)
  sample_msgs = dataset["train"][sample_ind-sample_range:sample_ind+sample_range]["text"]

  batch.append(f"{tokenizer.eos_token}{tokenizer.bos_token}".join(sample_msgs))
  batch_inds.append(sample_ind)

# %%
batch_encoded = tokenizer.batch_encode_plus(batch, truncation=True, padding=True, max_length=128)

# %%
batch_encoded

# %%
batch_encoded_list = [dict(zip(batch_encoded, t)) for t in zip(*batch_encoded.values())]

# %%
batch_masked = data_collator(batch_encoded_list)

# %%
batch_masked

# %%
batch_masked_strings = tokenizer.batch_decode(batch_masked["input_ids"])

# %%
fill_mask_results = list()
for example in batch_masked_strings:
  fill_mask_results.append(mask_pipe(example[3:-4])) # for stripping <s> and </s>

# %%
best_examples = list()
for example in fill_mask_results:
  best_score_res = list()
  for mask in example:
    best_score_res.append(sorted(mask, key=lambda x: x["score"])[-2])

  best_examples.append(best_score_res)

# %%
for orig, masked, predictions in zip(batch, batch_masked_strings, best_examples):
  unmasked = deepcopy(masked)
  for res in predictions:
    unmasked = unmasked.replace("<mask>", res["token_str"], 1)
  print("mask: " + masked)
  print("orig: <s>" + orig + "</s>")
  print("pred: " + unmasked)
  print()
# Out:
# mask: <s>OMEGALUL</s><s>TwitchUnity STRAIGHT PRIDE<mask>Unity STRAIGHT PRIDE TwitchUnity STRAIGHT PRIDE TwitchUnity STRAIGHT PRIDE TwitchUnity '</s><s><mask>ULW</s><s>mango<mask>co WOMBO COMBO</s><s>SHOW HEALING<mask> SHIELD LUL</s><s><mask> mid</s><s>Akali EleGiggle</s><s>24K DAMAGE D<mask><mask><mask><mask> LUL</s><s>Sm<mask> LUL</s><s>they took 36 MINUTES<mask> beat<mask> OMEG<mask>UL</s><s>AZIR DMG monkaW AKALI DM Minor LUL</s>
# orig: <s>OMEGALUL</s><s>TwitchUnity STRAIGHT PRIDE TwitchUnity STRAIGHT PRIDE TwitchUnity STRAIGHT PRIDE TwitchUnity STRAIGHT PRIDE TwitchUnity '</s><s>LULW</s><s>mangoFalco WOMBO COMBO</s><s>SHOW HEALING AND SHIELD LUL</s><s>better mid</s><s>Akali EleGiggle</s><s>24K DAMAGE DIFFERENCE MID LUL</s><s>Smartz LUL</s><s>they took 36 MINUTES to beat EF OMEGALUL</s><s>AZIR DMG monkaW AKALI DMG LULW</s><s>OMEGALUL</s><s>Hey mods, did you really think that slow mode will affect on me. I will let you know that I have multiple accounts in this chat right now. If you don’t believe me, I will copy and paste this on my other accounts right now</s><s>ZeRo MaGiC dAmAgE Kappa ZeRo MaGiC dAmAgE Kappa ZeRo MaGiC dAmAgE Kappa ZeRo MaGiC dAmAgE Kappa</s><s>YUSUI BrokeBack</s><s>YUSUI LULW</s><s>MODS OMEGALUL\</s><s>akali LUL</s><s>NA Akali</s><s>C R I N G E</s>
# pred: <s>OMEGALUL</s><s>TwitchUnity STRAIGHT PRIDE</s>Unity STRAIGHT PRIDE TwitchUnity STRAIGHT PRIDE TwitchUnity STRAIGHT PRIDE TwitchUnity '</s><s>LULW</s><s>mango Falco WOMBO COMBO</s><s>SHOW HEALING: SHIELD LUL</s><s> the mid</s><s>Akali EleGiggle</s><s>24K DAMAGE DOGMLK LUL</s><s>SmW LUL</s><s>they took 36 MINUTES TO beat it OMEGLUL</s><s>AZIR DMG monkaW AKALI DM Minor LUL</s>
#
# mask: <s>Kappa<mask>ide</s><s><mask><mask></s><s>Kappa<mask>ide</s><s>tobiasPRIDE evoPride</s><s>KappaPride</s><s>SHES NOT EVEN KOREAN</s><s>KappaPride</s><s>ially<mask><mask>ide</s><s><mask><mask>Pride</s><s>VapeNation</s><s>KappaPride</s><s><mask><mask>A<mask>ut filter</s><s>Kappa<mask>ide</s><s>haHAA</s><s>LUL</s><s>OMG</s><s>KappaPride KappaPr<mask></s><s>K<mask>Pride</s><s>EU AT RR LUL</s><s>i<mask> samsung for b</s>
# orig: <s>KappaPride</s><s>LUL</s><s>KappaPride</s><s>tobiasPRIDE evoPride</s><s>KappaPride</s><s>SHES NOT EVEN KOREAN</s><s>KappaPride</s><s>KappaPride</s><s>KappaPride</s><s>VapeNation</s><s>KappaPride</s><s>FUTA WutFace</s><s>KappaPride</s><s>haHAA</s><s>LUL</s><s>OMG</s><s>KappaPride KappaPride</s><s>KappaPride</s><s>EU AT RR LUL</s><s>i love samsung for bannin Galio PogChamp such a ResidentSleeper Champ</s>
# pred: <s>Kappa Pride</s><s>P:</s><s>Kappapride</s><s>tobiasPRIDE evoPride</s><s>KappaPride</s><s>SHES NOT EVEN KOREAN</s><s>KappaPride</s><s>ially Kappapride</s><s></s>aPride</s><s>VapeNation</s><s>KappaPride</s><s>.KAolut filter</s><s>Kappa Pride</s><s>haHAA</s><s>LUL</s><s>OMG</s><s>KappaPride KappaPrides</s><s>KarmaPride</s><s>EU AT RR LUL</s><s>i < samsung for b</s>
#
# mask: <s>WH OM<mask>ALUL</s><s>dardocyh acvademy lol</s><s>I hope 100T can<mask> in</s><s>TS<mask> choking needed<mask>S</s><s>same</s><s>i think theyido<mask> i think either c9 or tsm wont get in</s><s>Lov148<mask> new pantheon rework SoBayed SoBayed<mask>Bay<mask></s><s>L<mask> TSM Jatt</s><s>TSM, aka "Tribe of<mask> Monkeys," is a<mask> in Riot Games' Minor League that is often ridiculed for being washed-up and<mask> an owner that looks like Wukong. It is</s>
# mask: <s>RaccAttack RaccAttack RaccAttack</s><s>SONA ULT LUL</s><s>L<mask> LUL</s><s>CHI NA</s><s>LCK>LPL LUL</s><s>THIS JAYCE OMG</s><s>RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack</s><s>N<mask>URIIIIIIIII</s><s><mask>acc<mask></s><s>Racc<mask></s><s>gg</s><s>HES<mask> SANE<mask> LAN<mask> TOO WTF RAZ</s><s>RaccAttack<mask>z clap</s><s>Nice teamfiting idiots</s><s></s>
# orig: <s>RaccAttack RaccAttack RaccAttack</s><s>SONA ULT LUL</s><s>LPL LUL</s><s>CHI NA</s><s>LCK>LPL LUL</s><s>THIS JAYCE OMG</s><s>RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack</s><s>NUGURIIIIIIIII</s><s>RaccAttack</s><s>RaccAttack</s><s>gg</s><s>HES IN SANE IN LANE TOO WTF RAZ</s><s>RaccAttack ez clap</s><s>Nice teamfiting idiots</s><s>CAMPED BTW danO</s><s>LPL LUL</s><s>RaccAttack RaccAttack RaccAttack RaccAttack</s><s>Pog</s><s>LUL</s><s>LCK LCK LCK</s>
# pred: <s>RaccAttack RaccAttack RaccAttack</s><s>SONA ULT LUL</s><s>LUL LUL</s><s>CHI NA</s><s>LCK>LPL LUL</s><s>THIS JAYCE OMG</s><s>RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack RaccAttack</s><s>NUURIIIIIIIII</s><s> Racc Attack</s><s>Racc Attack</s><s>gg</s><s>HESO SANE! LANS TOO WTF RAZ</s><s>RaccAttack lolz clap</s><s>Nice teamfiting idiots</s><s></s>
#
# mask: <s>Loked yup<mask> LUL</s><s>NAICUUUUU</s><s>too bad he cant get out of China LUL</s><s>faker best<mask> LUL</s><s>BABY<mask>S mikyPizzaa</s><s>Faker WAS the<mask>, But isn't even<mask> of the best Mids in 2019 already, Stop being delusional and admit it, you 10 y/o fans LUL</s><s> 21 many po<mask><mask> in this chat</s><s>ADS WutFace</s><s>No it isn't, keep in mind they changed the entire roster and put in pros<mask> different mentality.</s><s> powered craps</s>
# orig: <s>LUL yup apparently LUL</s><s>NAICUUUUU</s><s>too bad he cant get out of China LUL</s><s>faker best mid LUL</s><s>BABY CAPS mikyPizzaa</s><s>Faker WAS the best, But isn't even one of the best Mids in 2019 already, Stop being delusional and admit it, you 10 y/o fans LUL</s><s>So many poopyboys in this chat</s><s>ADS WutFace</s><s>No it isn't, keep in mind they changed the entire roster and put in pros with different mentality.</s><s>bro craps feeds like half his games wtf</s><s>NA ULW</s><s>he was best mid at msi LOL</s><s>it will take time, but they can make it work</s><s>ResidentSleeper</s><s>DoinB will make worlds unlike Faker LUL</s><s>LEC PogChamp LCS ResidentSleeper LPL NotLikeThis LCK LUL</s><s>Faker WAS the best, But isn't even one of the best Mids in 2019 already, Stop being delusional and admit it, you 10 y/o fans LUL Rookie , and maybe Caps peaks even higher than him right now</s><s>calling someone washed up because the other players FINALLY caught up to his skill level LUL</s><s>what is this tune called</s><s>No u :)</s>
s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# mask: <s>KEKW</s><s>FREENUT KEKW</s><s>KINT ULT KEKW</s><s><mask> OMEAGALUL RI</s><s>GORI PLAYER OF<mask> SPL<mask> BTW</s><s>XMITHIE KE<mask>W</s><s>ICON WOULD HAVE GA</s><s>freeca kek</s><s>PEANUT GETTING<mask>APPED</s><s>C<mask>IUM</s><s>kiin KEKW</s><s>is this gonna be a Bo5??</s><s>ward = flash</s><s>MVP BTW<mask>EP</s><s>FREENUT<mask>UL</s><s>LUL LUL</s><s></s>
# orig: <s>KEKW</s><s>FREENUT KEKW</s><s>KINT ULT KEKW</s><s>G OMEAGALUL RI</s><s>GORI PLAYER OF THE SPLIT BTW</s><s>XMITHIE KEKW</s><s>ICON WOULD HAVE GA</s><s>freeca kek</s><s>PEANUT GETTING GAPPED</s><s>COPIUM</s><s>kiin KEKW</s><s>is this gonna be a Bo5??</s><s>ward = flash</s><s>MVP BTW YEP</s><s>FREENUT LUL</s><s>LUL LUL</s><s>Yasou 0-3 KEKW LUL</s><s>NO FLASH EZ TEAMFIGHT</s><s>Is NS going to worlds anyways KEKW</s><s>B03 OR B05???</s>
# pred: <s>KEKW</s><s>FREENUT KEKW</s><s>KINT ULT KEKW</s><s>K OMEAGALUL RI</s><s>GORI PLAYER OF A SPLASH BTW</s><s>XMITHIE KE KW</s><s>ICON WOULD HAVE GA</s><s>freeca kek</s><s>PEANUT GETTING HAPPED</s><s>CAMPIUM</s><s>kiin KEKW</s><s>is this gonna be a Bo5??</s><s>ward = flash</s><s>MVP BTW KEP</s><s>FREENUT KUL</s><s>LUL LUL</s><s></s>
#
# mask: <s>NICE TO dmg YOU SMILING LUL</s><s>HOPIUM</s><s>MorphinTime COPY MorphinTime THIS MorphinTime STATIC MorphinTime TO MorphinTime HELP MorphinTime FNATIC MorphinTime COPY MorphinTime THIS Morph<mask>Time STATIC MorphinTime TO MorphinTime HELP Morph<mask>Time FNATIC MorphinTime</s><s>widepeepoHappy</s><s>BWIPO CARRY THIS TEAM</s><s>widepeepoHappy</s><s><3</s><s>LET'S forsenE<mask> forsenE N<mask>QY for<mask>E<mask>'S</s>
# orig: <s>NICE TO SEE YOU SMILING LUL</s><s>HOPIUM</s><s>MorphinTime COPY MorphinTime THIS MorphinTime STATIC MorphinTime TO MorphinTime HELP MorphinTime FNATIC MorphinTime COPY MorphinTime THIS MorphinTime STATIC MorphinTime TO MorphinTime HELP MorphinTime FNATIC MorphinTime</s><s>widepeepoHappy</s><s>BWIPO CARRY THIS TEAM</s><s>widepeepoHappy</s><s><3</s><s>LET'S forsenE GO forsenE NISQY forsenE LET'S forsenE GO forsenE NISQY forsenE LET'S forsenE GO forsenE NISQY forsenE LET'S forsenE GO forsenE NISQY forsenE LET'S forsenE GO forsenE NISQY forsenE LET'S forsenE GO forsenE NISQY forsenE</s><s>IM HIGH ON COPIUM</s><s>Nisqy <3</s><s>happy fnc <3</s><s>COPIUM</s><s>widepeepoHappy</s><s>NISQY <3</s><s>WE BELIEVE <3</s><s>Belgium stronk</s><s>widebwipohappy</s><s>MorphinTime COPY MorphinTime THIS MorphinTime STATIC MorphinTime TO MorphinTime HELP MorphinTime FNATIC MorphinTime COPY MorphinTime THIS MorphinTime STATIC MorphinTime TO MorphinTime HELP MorphinTime FNATIC MorphinTime .</s><s>BWIPO KEKW</s><s>BWIPO widepeepoHappy</s>
# pred: <s>NICE TO dmg YOU SMILING LUL</s><s>HOPIUM</s><s>MorphinTime COPY MorphinTime THIS MorphinTime STATIC MorphinTime TO MorphinTime HELP MorphinTime FNATIC MorphinTime COPY MorphinTime THIS MorphinaTime STATIC MorphinTime TO MorphinTime HELP MorphInTime FNATIC MorphinTime</s><s>widepeepoHappy</s><s>BWIPO CARRY THIS TEAM</s><s>widepeepoHappy</s><s><3</s><s>LET'S forsenE Y forsenE NOOQY forENELET'S</s>

# %%
best_examples

# %%
mask_pipe("why is this Malphite on meta again <mask>")
# Out:
# [{'score': 0.9025630950927734,
#   'token': 116,
#   'token_str': '?',
#   'sequence': 'why is this Malphite on meta again?'},
#  {'score': 0.03233589977025986,
#   'token': 17487,
#   'token_str': '?',
#   'sequence': 'why is this Malphite on meta again?'},
#  {'score': 0.01631227135658264,
#   'token': 4,
#   'token_str': '.',
#   'sequence': 'why is this Malphite on meta again.'},
#  {'score': 0.006503658834844828,
#   'token': 38713,
#   'token_str': '???',
#   'sequence': 'why is this Malphite on meta again???'},
#  {'score': 0.005908921826630831,
#   'token': 28749,
#   'token_str': '??',
#   'sequence': 'why is this Malphite on meta again??'}]

# %%
mask_pipe("")

# %%
# it has not learned what copy pasta is, otherwise it could have predicted COMA
# 249134, KKOMA PUTTING ME IN A COMA ResidentSleeper KKOMA PUTTING ME IN A COMA ResidentSleeper
mask_pipe("KKOMA PUTTING ME IN A COMA ResidentSleeper KKOMA PUTTING ME IN A <mask> ResidentSleeper")
# Out:
# [{'score': 0.5533647537231445,
#   'token': 15823,
#   'token_str': ' COM',
#   'sequence': 'KKOMA PUTTING ME IN A COMA ResidentSleeper KKOMA PUTTING ME IN A COM ResidentSleeper'},
#  {'score': 0.20228534936904907,
#   'token': 5267,
#   'token_str': ' CA',
#   'sequence': 'KKOMA PUTTING ME IN A COMA ResidentSleeper KKOMA PUTTING ME IN A CA ResidentSleeper'},
#  {'score': 0.03358528017997742,
#   'token': 6247,
#   'token_str': ' CO',
#   'sequence': 'KKOMA PUTTING ME IN A COMA ResidentSleeper KKOMA PUTTING ME IN A CO ResidentSleeper'},
#  {'score': 0.015576242469251156,
#   'token': 8193,
#   'token_str': ' Commonwealth',
#   'sequence': 'KKOMA PUTTING ME IN A COMA ResidentSleeper KKOMA PUTTING ME IN A Commonwealth ResidentSleeper'},
#  {'score': 0.013505257666110992,
#   'token': 17088,
#   'token_str': ' Guatemala',
#   'sequence': 'KKOMA PUTTING ME IN A COMA ResidentSleeper KKOMA PUTTING ME IN A Guatemala ResidentSleeper'}]

# %% [markdown]
# ### Examples from unseen data

# %%
val_split_raw = glob.glob("/content/gdrive/MyDrive/nalcs_raw_data_fu/Copy of nalcs_nalcs1_w[268]d[1]_*.json")

# %%
def is_msg(msg):
  return "attributes" in msg.keys()

# %%
msgs = list()
for day_raw in val_split_raw:
  with open(day_raw, "r") as in_file:
    messages = json.load(in_file)
    msgs.extend([msg["attributes"]["message"] for msg in messages if is_msg(msg)])

# %%
len(msgs)
# Out:
# 193585

# %%
chunk_size = 10
batch_size = 25

chunks = list()
for i in range(int(len(msgs)/chunk_size)):
  chunk = msgs[i*chunk_size:min((i+1)*chunk_size, len(msgs))]
  chunks.append(f"{tokenizer.eos_token}{tokenizer.bos_token}".join(chunk))
  if len(chunks) == batch_size:
    break

# %%
len(chunks)
# Out:
# 25

# %%
batch_encoded_highlights = tokenizer.batch_encode_plus(chunks, truncation=True, padding=True, max_length=128)

# %%
batch_encoded_highlights

# %%
batch_encoded_highlights_list = [dict(zip(batch_encoded_highlights, t)) for t in zip(*batch_encoded_highlights.values())]

# %%
batch_masked_highlights = data_collator(batch_encoded_highlights_list)

# %%
batch_masked_highlights

# %%
batch_masked_highlights_strings = tokenizer.batch_decode(batch_masked_highlights["input_ids"])

# %%
fill_mask_highlights_results = list()
for example in batch_masked_highlights_strings:
  fill_mask_highlights_results.append(mask_pipe(example[3:-3])) # for stripping <s> and </s>

# %%
fill_mask_highlights_results[0]

# %%
best_examples_highlights = list()
for example in fill_mask_highlights_results:
  best_score_highlights_res = list()
  for mask in example:
    best_score_highlights_res.append(sorted(mask, key=lambda x: x["score"])[-2])

  best_examples_highlights.append(best_score_highlights_res)

# %%
for orig, masked, predictions in zip(chunks, batch_masked_highlights_strings, best_examples_highlights):
  unmasked = deepcopy(masked)
  for res in predictions:
    unmasked = unmasked.replace("<mask>", res["token_str"], 1)
  print("mask: " + masked)
  print("orig: <s>" + orig + "</s>")
  print("pred: " + unmasked)
  print()
# Out:
# mask: <s>Wut<mask></s><s><mask>ogChamp</s><s>PogChamp</s><s>Pog<mask></s><s>Lemon vs Aphro Keepo</s><s><mask>phrom<mask><mask>reygasm</s><s>LUL</s><s>Here we<mask></s><s>OMGScoots</s><s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>WutFace</s><s>PogChamp</s><s>PogChamp</s><s>PogChamp</s><s>Lemon vs Aphro Keepo</s><s>Aphromoo Kreygasm</s><s>LUL</s><s>Here we go</s><s>OMGScoots</s><s></s>
# pred: <s>Wutcher</s><s>PogChamp</s><s>PogChamp</s><s>Poglia</s><s>Lemon vs Aphro Keepo</s><s>Aphrom & threygasm</s><s>LUL</s><s>Here we were</s><s>OMGScoots</s><s></s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# mask: <s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>A<mask>romoo Pog<mask></s><s>4Head 4Head 4Head 4Head 4Head</s><s>A<mask>ro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s><mask>RO POINTING OUT HIS NEXT BOOT<mask> CALL, SHOTS FIRED</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head 4Head 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIR
s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>holy moly</s><s>First</s><s>FUNgineer 🙏 vs 👈 TriHard</s><s>👈 TriHard</s><s>NA WutFace</s><s>NA < EU</s><s>🙏 vs 👈</s><s>fist</s><s>learn english WutFace</s><s>Report @treyhax feeding rop plx</s>
# pred: <s>holy moly</s><s>First</s><s>FUNgineer 🙏 vs 👈 TriHard</s><s>👈</s>Hard</s><s>. WutFace</s><s>NA < EU</s><s>🙏 vs �p</s><s>fist</s><s>learn english WutFace</s><s>Report @treyhax feeding</s>p plx</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# mask: <s>:)</s><s>👈 RlyTho</s><s>56 minutes D:</s><s>first</s><s>second</s><s>L<mask> Daddy VoHiYo</s><s>#first</s><s>first</s><s>lemon<mask> starting to look more and<mask> like vsau<mask> LUL</s><s>20<mask><mask>X SwiftRage</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>:)</s><s>👈 RlyTho</s><s>56 minutes D:</s><s>first</s><s>second</s><s>Lemon Daddy VoHiYo</s><s>#first</s><s>first</s><s>lemon is starting to look more and more like vsauce LUL</s><s>20% TAX SwiftRage</s>
# pred: <s>:)</s><s>👈 RlyTho</s><s>56 minutes D:</s><s>first</s><s>second</s><s>Lil Daddy VoHiYo</s><s>#first</s><s>first</s><s>lemona starting to look more and less like vsauf LUL</s><s>20.-X SwiftRage</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# mask: <s><mask>DestructFFER DID YOU<mask> ME<mask>Destructoid</s><s>if trump builds the wall Mexico will<mask> the next great power PogChamp</s><s>Tw<mask> chat - today I lost my<mask>.<mask> I have BibleThump in the<mask><mask><mask></s><s>@Geekomysteriousseal report meh<mask>Hard</s><s>FIRST PogChamp</s><s>inglish in 2k17<mask>UL</s><s>@IfYouReadThisUr<mask>appaPride,<mask>'m KappaPride<mask>elsBadMan</s><s>👈 cmonB<mask>h</s><s>Time to watch some fking<mask>fiesta 50min</s>
# orig: <s>MrDestructoid DID YOU CALL ME MrDestructoid</s><s>if trump builds the wall Mexico will be the next great power PogChamp</s><s>Twitch chat - today I lost my wallet. Can I have BibleThump in the chat please?</s><s>@Geekomysteriousseal report meh TriHard</s><s>FIRST PogChamp</s><s>inglish in 2k17 LUL</s><s>@IfYouReadThisUrKappaPride, I'm KappaPride FeelsBadMan</s><s>👈 cmonBruh</s><s>Time to watch some fking clownfiesta 50min games BrokeBack NA is so fking bad this year</s><s>Lemon PogChamp</s>
# pred: <s>#DestructFFER DID YOU CALL ME?Destructoid</s><s>if trump builds the wall Mexico will become the next great power PogChamp</s><s>Twas chat - today I lost my job. But I have BibleThump in the back</s>!</s><s>@Geekomysteriousseal report meh DieHard</s><s>FIRST PogChamp</s><s>inglish in 2k17 BUL</s><s>@IfYouReadThisUrNappaPride,I'm KappaPrideAngelsBadMan</s><s>👈 cmonBokeh</s><s>Time to watch some fking</s>fiesta 50min</s>
#
# mask: <s>sneakyLemon<mask>�� vs 👈 TriHard</s><s><mask>ible<mask>ump 7</s><s>🙏 vs 👈</s><s>�<mask><mask><mask></s><s>🤔</s><s>¯\_(ツ)_/¯</s><s>eu>na</s><s>@trey<mask>ax wanna watch clown porn?</s><s><mask>fu only in Mexico</s><s>@Donglet, KappaPride</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>sneakyLemon 🙏 vs 👈 TriHard</s><s>BibleThump 7</s><s>🙏 vs 👈</s><s>👈 TriHard</s><s>🤔</s><s>¯\_(ツ)_/¯</s><s>eu>na</s><s>@treyhax wanna watch clown porn?</s><s>stfu only in Mexico</s><s>@Donglet, KappaPride</s>
# pred: <s>sneakyLemon----------------�� vs 👈 TriHard</s><s> collapsible chump 7</s><s>🙏 vs 👈</s><s>�1</s>!</s><s>🤔</s><s>¯\_(ツ)_/¯</s><s>eu>na</s><s>@treyjax wanna watch clown porn?</s><s>/fu only in Mexico</s><s>@Donglet, KappaPride</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# mask: <s>BibleThump</s><s><mask>Movi_, BibleThump //</s><s>first VoHiYo</s><s>`\≡\(Q)/≡/`</s><s>FRE<mask>M</s><s>type 1 if u watched yuri on ice KappaPride</s><s>@<mask>ekomysteriousseal w<mask><mask><mask>utFace</s><s>OM<mask>Scoots �<mask>� vsprice<mask> TriHard</s><s>🔫 TriHard GIMME agitation MONEY</s><s>This is funny :)</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>BibleThump</s><s>@Movi_, BibleThump //</s><s>first VoHiYo</s><s>`\≡\(Q)/≡/`</s><s>FREESM</s><s>type 1 if u watched yuri on ice KappaPride</s><s>@Geekomysteriousseal wtf no WutFace</s><s>OMGScoots 🙏 vs 👈 TriHard</s><s>🔫 TriHard GIMME YOUR MONEY</s><s>This is funny :)</s>
# pred: <s>BibleThump</s><s>-Movi_, BibleThump //</s><s>first VoHiYo</s><s>`\≡\(Q)/≡/`</s><s>FREATM</s><s>type 1 if u watched yuri on ice KappaPride</s><s>@cheekomysteriousseal wtf- smutFace</s><s>OM-Scoots �$� vsprice: TriHard</s><s>🔫 TriHard GIMME agitation MONEY</s><s>This is funny :)</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
#
# mask: <s>🙏<mask> 👈</s><s>👈 TriHard</s><s>NOWipping TIME<mask> TRIG<mask>ED NA</s><s>Trump said Mexico<mask> pay for the wall, He meant ME - x<mask> FailFish</s><s>NA<mask>Sleeper</s><s><mask>RE<mask>G</s><s><mask>MON LOOKS<mask> BADASSSinel, O<mask> SCHOOL SUP ATCHUP Kreygasm</s><s>NA IS<mask>ANKES AND KOREANS</s><s>@Jormix -<mask> word mexico<mask> great will never be associated ever,,,,EVER!</s><s>Free USA Mexico sucks Kappa</s><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>🙏 vs 👈</s><s>👈 TriHard</s><s>NOW ITS TIME TO TRIGGERED NA</s><s>Trump said Mexico will pay for the wall , He meant ME - xico FailFish</s><s>NA ResidentSleeper</s><s>FREELG</s><s>LEMON LOOKS SO BADASSSSS, OLD SCHOOL SUP ATCHUP Kreygasm</s><s>NA IS DANKES AND KOREANS</s><s>@Jormix - the word mexico and great will never be associated ever,,,,EVER!</s><s>Free USA Mexico sucks Kappa</s>
# pred: <s>🙏♥ 👈</s><s>👈 TriHard</s><s>NOWipping TIME I TRIGGED NA</s><s>Trump said Mexico will pay for the wall, He meant ME - xxx FailFish</s><s>NA-Sleeper</s><s> THREGGG</s><s>COMMON LOOKS LIKE BADASSSinel, OAK SCHOOL SUP ATCHUP Kreygasm</s><s>NA IS BLANKES AND KOREANS</s><s>@Jormix - the word mexico was great will never be associated ever,,,,EVER!</s><s>Free USA Mexico sucks Kappa</s><pad><pad><pad><pad><pad><pad><pad>
#
# mask: <s
s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# orig: <s>@izzycrystal Yup. Named Trump ;P</s><s>ftnaHEY</s><s>Trump gets 10 bans who is next Kappa</s><s>DatSheffy Taliyah ulted Mexico DatSheffy</s><s>CLG CLG CLG</s><s>EU without NA in Wars 4Head</s><s>@Jormix godd one haha</s><s>sneakyW WHERE THE *** ARE MY SNEAKY SUBS sneakyW</s><s></s><s>Is there literally going to be music playing and a still screen for the next hour? 🤔</s>
# pred: <s>Dizzycrystal Yup perce Named Trump ;P</s><s>ftnaHEY</s><s>Trump gets 10 bans who comes next Kappa</s><s>DatSheffy Taliyah ulted Mexico DatSheffy</s><s>CLG CLGCLG</s><s>EU without NA in Wars 4Head</s><s>@Jormix godd one haha</s><s>sneakyW FUCK THE *** ARE MY WHEAKY SUKE sneakyW</s><s></s><s>Is there literally going to be music playing and a still screen for the next hour? 🤔</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>

# %%
"<s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head 4Head 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s>"
# Out:
# '<s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head 4Head 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s>'

# %%
mask_pipe("<s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head 4Head 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s>")
# Out:
# [{'score': 0.1275135576725006,
#   'token': 8,
#   'token_str': ' and',
#   'sequence': 'yes and such musicLemon is readyHeyGuysAphromoo PogChamp4Head 4Head 4Head 4Head 4HeadAphro laughing at lemon lulThis is the kind of music you listen to white highLemonNation PogChampAPHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED'},
#  {'score': 0.042079195380210876,
#   'token': 18,
#   'token_str': "'s",
#   'sequence': "yes's such musicLemon is readyHeyGuysAphromoo PogChamp4Head 4Head 4Head 4Head 4HeadAphro laughing at lemon lulThis is the kind of music you listen to white highLemonNation PogChampAPHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED"},
#  {'score': 0.032024286687374115,
#   'token': 16,
#   'token_str': ' is',
#   'sequence': 'yes is such musicLemon is readyHeyGuysAphromoo PogChamp4Head 4Head 4Head 4Head 4HeadAphro laughing at lemon lulThis is the kind of music you listen to white highLemonNation PogChampAPHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED'},
#  {'score': 0.0292093213647604,
#   'token': 117,
#   'token_str': ' no',
#   'sequence': 'yes no such musicLemon is readyHeyGuysAphromoo PogChamp4Head 4Head 4Head 4Head 4HeadAphro laughing at lemon lulThis is the kind of music you listen to white highLemonNation PogChampAPHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED'},
#  {'score': 0.020822906866669655,
#   'token': 55,
#   'token_str': ' more',
#   'sequence': 'yes more such musicLemon is readyHeyGuysAphromoo PogChamp4Head 4Head 4Head 4Head 4HeadAphro laughing at lemon lulThis is the kind of music you listen to white highLemonNation PogChampAPHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED'}]

# %%
mask_pipe("<s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head <mask><mask> 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s>")
# Out:
# [[{'score': 0.6749449968338013,
#    'token': 204,
#    'token_str': ' 4',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head 4<mask> 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.07971546798944473,
#    'token': 306,
#    'token_str': '4',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head4<mask> 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.05696845054626465,
#    'token': 2,
#    'token_str': '</s>',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head</s><mask> 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.0371735580265522,
#    'token': 155,
#    'token_str': ' 3',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head 3<mask> 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.03685128688812256,
#    'token': 132,
#    'token_str': ' 2',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head 2<mask> 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'}],
#  [{'score': 0.5844506025314331,
#    'token': 28873,
#    'token_str': 'Head',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head<mask>Head 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.027991948649287224,
#    'token': 3928,
#    'token_str': ' Head',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head<mask> Head 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.014935702085494995,
#    'token': 3628,
#    'token_str': 'head',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head<mask>head 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.007249601650983095,
#    'token': 28285,
#    'token_str': 'Heart',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head<mask>Heart 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'},
#   {'score': 0.005826991051435471,
#    'token': 14323,
#    'token_str': 'Top',
#    'sequence': '<s><s>yes</s><s>Kreygasm such music</s><s>Lemon is ready</s><s>HeyGuys</s><s>Aphromoo PogChamp</s><s>4Head 4Head 4Head<mask>Top 4Head</s><s>Aphro laughing at lemon lul</s><s>This is the kind of music you listen to white high</s><s>LemonNation PogChamp</s><s>APHRO POINTING OUT HIS NEXT BOOTY CALL, SHOTS FIRED</s></s>'}]]

# %% [markdown]
# ### Perplexity
#
# it may not be the right metric for measuring MLMs, but will give a hint at how well it is doing
#
# It is simply calculated by raising e to the power of the eval loss.
#
# $e^{validation\_loss}$

# %%
training_args = TrainingArguments(
        output_dir="./RoBERTa/evaluation_test",
        overwrite_output_dir=False,
        num_train_epochs=3,
        per_device_train_batch_size=64,
        save_steps=10_000,
        save_total_limit=4,
        prediction_loss_only=True,
        evaluation_strategy="steps",
        eval_steps=5_000,
        report_to="all",
        per_gpu_eval_batch_size=8
    )

trainer = Trainer(
        model=model,
        args=training_args,
        data_collator=data_collator,
        train_dataset=None,
        eval_dataset=ds_val_grouped
    )

# %%
eval_res = trainer.evaluate()
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForMaskedLM.forward` and have been ignored: special_tokens_mask. If special_tokens_mask are not expected by `RobertaForMaskedLM.forward`,  you can safely ignore this message.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# ***** Running Evaluation *****
#   Num examples = 720455
#   Batch size = 8
#     <div>
#
#       <progress value='292' max='90057' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  292/90057 00:22 < 1:53:57, 13.13 it/s]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-8f6de774e511> in <module>
# ----> 1 eval_res = trainer.evaluate()
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    2289             prediction_loss_only=True if self.compute_metrics is None else None,
#    2290             ignore_keys=ignore_keys,
# -> 2291             metric_key_prefix=metric_key_prefix,
#    2292         )
#    2293
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    2456
#    2457             # Prediction step
# -> 2458             loss, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    2459
#    2460             if is_torch_tpu_available():
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in prediction_step(self, model, inputs, prediction_loss_only, ignore_keys)
#    2669                 if has_labels:
#    2670                     with self.autocast_smart_context_manager():
# -> 2671                         loss, outputs = self.compute_loss(model, inputs, return_outputs=True)
#    2672                     loss = loss.mean().detach()
#    2673
#
# /usr/local/lib/python3.7/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    2041         else:
#    2042             labels = None
# -> 2043         outputs = model(**inputs)
#    2044         # Save past state if it exists
#    2045         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, output_attentions, output_hidden_states, return_dict)
#    1107             output_attentions=output_attentions,
#    1108             output_hidden_states=output_hidden_states,
# -> 1109             return_dict=return_dict,
#    1110         )
#    1111         sequence_output = outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     859             output_attentions=output_attentions,
#     860             output_hidden_states=output_hidden_states,
# --> 861             return_dict=return_dict,
#     862         )
#     863         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     532                     encoder_attention_mask,
#     533                     past_key_value,
# --> 534                     output_attentions,
#     535                 )
#     536
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     416             head_mask,
#     417             output_attentions=output_attentions,
# --> 418             past_key_value=self_attn_past_key_value,
#     419         )
#     420         attention_output = self_attention_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     347             output_attentions,
#     348         )
# --> 349         attention_output = self.output(self_outputs[0], hidden_states)
#     350         outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#     351         return outputs
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, input_tensor)
#     298         hidden_states = self.dense(hidden_states)
#     299         hidden_states = self.dropout(hidden_states)
# --> 300         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#     301         return hidden_states
#     302
#
# KeyboardInterrupt:

# %%
eval_res

# %%
# simple perplexity
np.exp(eval_res["eval_loss"])

# %%
np.exp(3.914557933807373)
# Out:
# 50.12690720133711

# %% [markdown]
# ### Preprocess Fu et al. 2017 data

# %%
ds_fu_raw = load_dataset('text', data_files={'train': "data/fu_raw_msgs_combined_cleaned.txt"})

# %%
ds_fu_raw_tok = ds_fu_raw["train"].map(tokenize_function, batched=True, num_proc=2, remove_columns=["text"])

# %%
ds_fu_raw_grouped = ds_fu_raw_tok.map(
        group_texts,
        fn_kwargs={"tokenizer": tokenizer},
        batched=True,
        batch_size=1000,
        num_proc=2
    )
# Out:
# #0:   0%|          | 0/981 [00:00<?, ?ba/s]
# #1:   0%|          | 0/981 [00:00<?, ?ba/s]

# %%
ds_fu_raw_grouped.save_to_disk("./data/fu_raw_roberta")

# %%
ds_fu_raw_grouped = datasets.load_from_disk("./data/fu_raw_roberta")

# %% [markdown]
# ### Perplexity on Fu et al

# %%
training_args = TrainingArguments(
        output_dir="./RoBERTa/evaluation_test",
        overwrite_output_dir=False,
        num_train_epochs=3,
        per_device_train_batch_size=64,
        save_steps=10_000,
        save_total_limit=4,
        prediction_loss_only=True,
        evaluation_strategy="steps",
        eval_steps=5_000,
        report_to="all",
        per_gpu_eval_batch_size=8
    )

trainer = Trainer(
        model=model,
        args=training_args,
        data_collator=data_collator,
        train_dataset=None,
        eval_dataset=ds_fu_raw_grouped
    )
# Out:
# PyTorch: setting up devices

# %%
eval_res = trainer.evaluate()
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForMaskedLM.forward` and have been ignored: special_tokens_mask. If special_tokens_mask are not expected by `RobertaForMaskedLM.forward`,  you can safely ignore this message.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# ***** Running Evaluation *****
#   Num examples = 125360
#   Batch size = 8
#     <div>
#
#       <progress value='16659' max='15670' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15670/15670 26:01]
#     </div>
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.

# %%
eval_res
# Out:
# {'eval_loss': 3.915489912033081,
#  'eval_runtime': 1410.3449,
#  'eval_samples_per_second': 88.886,
#  'eval_steps_per_second': 11.111}

# %%
# simple perplexity
np.exp(eval_res["eval_loss"])
# Out:
# 50.17364616383546
